# %% [markdown]
# Objective Of Exploratory Data Analysis
#
# -->To Bring out the quality of the data and make it ready for Machine Learning Modeling

# %%
#importing libraries
import numpy as np          #Faster Data Processing (arrays)
import pandas as pd         #Mainly For EDA Purpose

# %%
#Loading the data
data = pd.read_csv('titanic.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Understanding the data ------->info(),describe(),coloumns(),unique(),value_count()


data.info()           #Complte Information of Dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#Reading Columns
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#We will seprate the columns

data.dtypes;                                         #Displays the data types of each column
data.select_dtypes(include = 'object');              #Object Columns
data.select_dtypes(include = 'int');                  #integer coloumns
data.select_dtypes(include = ['int','float'])
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
#Getting Total number of passengers in ship
print("Total Number of passengers in the ship are",len(data))
# Out:
# Total Number of passengers in the ship are 891

# %%
#Statistical Distribution ---> describe()

print("Statistical Distribution of the data:")    
data.describe()                                    #default ---> numerical coloumns only
# Out:
# Statistical Distribution of the data:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.describe(include='object')   #desribe ---> for objects
#top returns most occuring value
#frequency returns count of most occuring value
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
#We Try to Understand the unique values in coloumns
data['Sex'].unique()             #unique values of Coloumn Sex
# Out:
# array(['male', 'female'], dtype=object)

# %%
data['Age'].unique()             #unique values of Coloumn Age
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
data['Embarked'].unique()             #unique values of Coloumn Embarked
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
data['Pclass'].unique()            #unique values of Coloumn Pclass
# Out:
# array([3, 1, 2], dtype=int64)

# %%
data['Survived'].unique()          #unique values of Coloumn Survived
# Out:
# array([0, 1], dtype=int64)

# %%
data['SibSp'].unique()          #unique values of Coloumn SibSp
# Out:
# array([1, 0, 3, 4, 2, 5, 8], dtype=int64)

# %%
data['Parch'].unique()             #unique values of Coloumn Parch
# Out:
# array([0, 1, 2, 5, 3, 4, 6], dtype=int64)

# %%
#Count of each uniuqe value
data['Sex'].value_counts()       #Count of uniuqe value of coloumn Sex
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
data['Survived'].value_counts()       #Count of uniuqe value of coloumn Survived
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
data['Pclass'].value_counts()       #Count of uniuqe value of coloumn Pclass
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
data['Pclass'].value_counts(ascending = True)
# Out:
# Pclass
# 2    184
# 1    216
# 3    491
# Name: count, dtype: int64

# %%
data['Embarked'].value_counts()      #Count of uniuqe value of coloumn Embarked
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
data['Age'].value_counts()      #Count of uniuqe value of coloumn Age
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
data['Age'].value_counts().head(30)         #head(x)--->Returrns top x samples(by default = 5)
# Out:
# Age
# 24.0    30
# 22.0    27
# 18.0    26
# 19.0    25
# 28.0    25
# 30.0    25
# 21.0    24
# 25.0    23
# 36.0    22
# 29.0    20
# 32.0    18
# 35.0    18
# 27.0    18
# 26.0    18
# 16.0    17
# 31.0    17
# 20.0    15
# 34.0    15
# 33.0    15
# 23.0    15
# 39.0    14
# 40.0    13
# 17.0    13
# 42.0    13
# 45.0    12
# 38.0    11
# 50.0    10
# 2.0     10
# 4.0     10
# 44.0     9
# Name: count, dtype: int64

# %%
#to get random samples in dataset
print("Random 15 Samples:")
data.sample(15)
# Out:
# Random 15 Samples:
#      PassengerId  Survived  Pclass  \
# 126          127         0       3
# 39            40         1       3
# 300          301         1       3
# 402          403         0       3
# 418          419         0       2
# 278          279         0       3
# 878          879         0       3
# 431          432         1       3
# 639          640         0       3
# 528          529         0       3
# 770          771         0       3
# 416          417         1       2
# 666          667         0       2
# 818          819         0       3
# 156          157         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 126                                McMahon, Mr. Martin    male   NaN      0
# 39                         Nicola-Yarred, Miss. Jamila  female  14.0      1
# 300           Kelly, Miss. Anna Katherine "Annie Kate"  female   NaN      0
# ...

# %% [markdown]
#
#
#                                                  Data Visulization

# %%
#Data Visulization ---> Matplotlib,seaborn,ploty
import matplotlib.pyplot as plt

# %%
#Distribution of Age
#Display the count on bars in histogram
counts,edges,bars = plt.hist(data['Age'],bins=25,color='purple')
print(counts)
print(bars)
plt.xlabel("Age")
plt.ylabel("Count")
plt.bar_label(bars)
plt.title("Age Distribution")
plt.show()
# Out:
# [30. 17. 15.  9. 29. 64. 67. 70. 83. 62. 51. 40. 35. 27. 35. 23. 15.  9.
#  11. 11.  4.  2.  3.  1.  1.]
# <BarContainer object of 25 artists>

# %% [markdown]
#                                             Bar Plots Representation

# %%
#Bar Plot Representation(Only For Objects(Categorical data))
data['Sex'].value_counts().plot(kind = 'bar',color='red')
# Out:
# <Axes: xlabel='Sex'>

# %%
#Bar Plot Representation For Column Sex
data['Sex'].value_counts().plot(kind = 'barh',color='red')
# Out:
# <Axes: ylabel='Sex'>

# %%
#Bar Plot Representation of Survived vs Sex
plt.bar(data['Survived'],data['Sex'],color = 'yellow')
plt.xlabel("Survived Rate")
plt.ylabel("Gender")
plt.title("Gender Survived Distribution")
plt.show()

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
#index-->keys(coloumn)
#labels-->values

#549/(549+342)
index = data['Survived'].value_counts().keys().tolist()
print(index)
labels = data['Survived'].value_counts().values.tolist()
print(labels)
# Out:
# [0, 1]
# [549, 342]

# %% [markdown]
#
#                                                     Pie Charts Representation

# %%
#Pie Charts For Column Survive
plt.pie(x = labels,
        labels = ['Dead','Alive'],
        colors = ['blue','gold'],
        autopct = "%.1f%%",
         shadow = True)
plt.title('Survived Distribution')
plt.legend()
plt.show()

# %%
#Pie Charts For Column Sex
plt.pie(x = [577,314],
        labels = ['Male','Female'],
        colors = ['red','pink'],
        autopct = "%.1f%%",
         shadow = True)
plt.title('Gender(SEX) Distribution')
plt.legend()
plt.show()
